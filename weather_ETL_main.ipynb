# %% [markdown]
# #### Importing the necessary child notebooks

# %%
# %run "./weather_ETL_dimensions"

# %%
# %run "./weather_ETL_schemas"

# %%
# %run "./weather_ETL_logger"

# %%
# %run "./weather_ETL_functions"

# %%
# %run "./weather_ETL_fact"
# Out:
# ...
#   Using cached python_dotenv-1.0.0-py3-none-any.whl (19 kB)
# ...
# WARNING: You are using pip version 21.2.4; however, version 23.1.2 is available.
# You should consider upgrading via the '/local_disk0/.ephemeral_nfs/envs/pythonEnv-21368613-3962-4b29-9f70-e41c6aad250f/bin/python -m pip install --upgrade pip' command.

# %% [markdown]
# #### Creating the necessary dimensional_tables

# %%
create_dim_date('2023-01-01', '2023-12-31')

# %%
create_dim_time('00:00:00', '23:59:59', '1 hour')

# %%
create_dim_city()

# %% [markdown]
# #### ETL Pipeline

# %%
# Main LOOP
df_raw = get_raw('RAW', 'weather_raw', 'loading raw data', 'city')
df_processed = get_processed_data('PROCESSED', 'processed_data', 'processing the data', df_raw)
insert_into_weather_hourly('FACT INSERTION', 'fact_weather_hourly', 'inserting hourly data', df_processed)
insert_into_weather_daily('FACT INSERTION DAILY', 'fact_weather_daily', 'inserting daily data', 'data')
# Out:
# DataFrame[coord: struct<lon:float,lat:float>, weather: array<struct<id:int,main:string,description:string,icon:string>>, base: string, main: struct<temp:float,feels_like:float,temp_min:float,temp_max:float,pressure:int,humidity:int,sea_level:int,grnd_level:int>, visibility: int, wind: struct<speed:float,deg:int,gust:string>, clouds: struct<all:int>, dt: int, sys: struct<country:string,sunrise:int,sunset:int>, timezone: int, id: int, name: string, cod: int] 2023-06-08 08:36:35 2023-06-08 08:39:47
# Out[92]: DataFrame[date_alt_key: date, time_alt_key: string, id: double, name: string, lat: float, lon: float, temp: float, temp_min: float, temp_max: float, pressure: int, humidity: int, visibility: int, wind_speed: float, wind_deg: int, wind_gust: string, clouds_all: int, load_run_id: string, created_on: timestamp, created_by: string]
